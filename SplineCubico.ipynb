# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate as CubicSpline

# %%
#Datos de ejemplo para interpolar (puedes cambiar estos valores)
x = np.array([1, 2, 3, 4, 5])
y= np.array([2, 3, 5, 7, 3])

# %%
#Crear el spline cúbico
spline = CubicSpline.CubicSpline(x, y, bc_type='natural')

#Coeficientes del spline cubico
print("Coeficientes por tramo:\n", spline.c)
# Out:
# Coeficientes por tramo:
#  [[ 1.60714286e-01  1.96428571e-01 -1.94642857e+00  1.58928571e+00]
#  [ 1.11022302e-16  4.82142857e-01  1.07142857e+00 -4.76785714e+00]
#  [ 8.39285714e-01  1.32142857e+00  2.87500000e+00 -8.21428571e-01]
#  [ 2.00000000e+00  3.00000000e+00  5.00000000e+00  7.00000000e+00]]

# %%
#Graficar Spline
# Puntos para evaluar el spline (suave)
x_new = np.linspace(x.min(), x.max(), 100)
y_new = spline(x_new)

# Gráfica
plt.figure(figsize=(8, 5))
plt.plot(x, y, 'ro', label='Datos originales')
plt.plot(x_new, y_new, 'b-', label='Spline cúbico')
plt.title('Interpolación con Splines Cúbicos', fontsize=14)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
